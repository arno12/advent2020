# %%
import pandas as pd

# %%
# Opening the data correctly needed to be done using the regular Python open function as the read_csv failed to use \n\n correctly
with open('../inputs/advent6.txt') as file:
    data = file.read()

passport_lines = data.split('\n\n')

passport_lines_merged = [line.replace('\n','') for line in passport_lines]
passport_lines_sep = [line.replace('\n','_') for line in passport_lines]

df = pd.DataFrame({'raw':passport_lines_merged, 'sep':passport_lines_sep})

df
# Out:
#                                                    raw  \
# 0                                         vvxvvxnclmbv
# 1              odgpnwqxhbitspqwsnxihogdbtpogiwxdhqbsnt
# 2                                                   qo
# 3    apulnqresohvktxcymzibdwgsigdvakmlyxhetopnubwzr...
# 4                                                 owwo
# ..                                                 ...
# 460                    knfheaukanehufunekfaklcsnemaufy
# 461      yhuvigcrprivgypcuhurphgvciyiyhrcvupgvuphryicg
# 462      flozkyvhnwxrfvpsybhlwrzhzqvmfgrlirholckaveszf
# 463                           gypwufzagspwqmuyzyogwpzu
# 464                                                coc
#
#                                                    sep
# 0                                     v_vx_v_vx_nclmbv
# 1            odgpnwqxhbits_pqwsnxihogdbt_pogiwxdhqbsnt
# 2                                                  q_o
# 3    apulnqresohvktxcymzibdwg_sigdvakmlyxhetopnubwz...
# 4                                                ow_wo
# ..                                                 ...
# 460                 knfheau_kanehuf_unekfa_klcsnemaufy
# 461  yhuvigcrp_rivgypcuh_urphgvciy_iyhrcvupg_vuphryicg
# 462   flozkyvhnwxr_fvpsybhlwrz_hzqvmfgrl_irholckaveszf
# 463                         gypwufz_agspwqmuyz_yogwpzu
# 464                                              c_oc_
#
# [465 rows x 2 columns]

# %%
# Part A
# The length of a set counts unique occurences of the characters inside it
df['unique_answers'] = df.apply(lambda x: len(set(x['raw'])), axis=1)

sum(df['unique_answers'])
# Out:
# 6443

# %%
# Part B - 
# You don't need to identify the questions to which anyone answered "yes"; 
# you need to identify the questions to which everyone answered "yes"!
splitted_list = [item.split("_") for item in passport_lines_sep]

def get_common_answers_count(df):
    sub_list = [item for item in df["sep"].split("_")]
    common_letters = set(sub_list[0])
    for item in sub_list[1:]:
        common_letters &= set(item)
    return len(common_letters)

df['common_answers'] = df.apply(get_common_answers_count, axis=1)

df
# Out:
#                                                    raw  \
# 0                                         vvxvvxnclmbv
# 1              odgpnwqxhbitspqwsnxihogdbtpogiwxdhqbsnt
# 2                                                   qo
# 3    apulnqresohvktxcymzibdwgsigdvakmlyxhetopnubwzr...
# 4                                                 owwo
# ..                                                 ...
# 460                    knfheaukanehufunekfaklcsnemaufy
# 461      yhuvigcrprivgypcuhurphgvciyiyhrcvupgvuphryicg
# 462      flozkyvhnwxrfvpsybhlwrzhzqvmfgrlirholckaveszf
# 463                           gypwufzagspwqmuyzyogwpzu
# 464                                                coc
#
#                                                    sep  unique_answers  \
# 0                                     v_vx_v_vx_nclmbv               7
# 1            odgpnwqxhbits_pqwsnxihogdbt_pogiwxdhqbsnt              13
# 2                                                  q_o               2
# 3    apulnqresohvktxcymzibdwg_sigdvakmlyxhetopnubwz...              24
# 4                                                ow_wo               2
# ..                                                 ...             ...
# 460                 knfheau_kanehuf_unekfa_klcsnemaufy              12
# 461  yhuvigcrp_rivgypcuh_urphgvciy_iyhrcvupg_vuphryicg               9
# 462   flozkyvhnwxr_fvpsybhlwrz_hzqvmfgrl_irholckaveszf              22
# 463                         gypwufz_agspwqmuyz_yogwpzu              12
# 464                                              c_oc_               2
#
#      common_answers
# 0                 1
# 1                13
# 2                 0
# 3                24
# 4                 2
# ..              ...
# 460               6
# 461               9
# 462               6
# 463               6
# 464               0
#
# [465 rows x 4 columns]

# %%
# This outputs the results - 1 because the last parsed line contains an extra "_"
sum(df['common_answers'])
# Out:
# 3231
